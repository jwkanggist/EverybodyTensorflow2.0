# %% [markdown]
# <a href="https://colab.research.google.com/github/jwkanggist/EverybodyTensorflow2.0/blob/master/lab18_mobilenet_cifar100_tf2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LAB18: Mobilenet for Cifar100
#
# Depthwise-separable *convolution을* 구현하여 moblienet을 만들어 보자
# - Cifar100 datatset을 위한 실험

# %%
# preprocessor parts

from __future__ import absolute_import, division, print_function, unicode_literals

# Install TensorFlow
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard

import numpy as np
import pandas as pd

from matplotlib import cm
from matplotlib import gridspec
import matplotlib.pyplot as plt

from datetime import datetime
# Out:
# TensorFlow 2.x selected.

# %%
  # for Tensorboard use
  LOG_DIR = 'drive/data/tb_logs'
	
  # !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
  # !unzip ngrok-stable-linux-amd64.zip
	
  import os
  if not os.path.exists(LOG_DIR):
    os.makedirs(LOG_DIR)
	  
  get_ipython().system_raw(
      'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
      .format(LOG_DIR))
	
  get_ipython().system_raw('./ngrok http 6006 &')
	
  # !curl -s http://localhost:4040/api/tunnels | python3 -c \
      "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# --2020-01-17 12:43:58--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 3.223.119.4, 52.203.255.14, 3.225.101.71, ...
# Connecting to bin.equinox.io (bin.equinox.io)|3.223.119.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  6.44MB/s    in 2.0s
#
# 2020-01-17 12:44:01 (6.44 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# https://b226281d.ngrok.io

# %%
# dataset loading part
# 데이터 파이프라인 부분 

cifar100 = tf.keras.datasets.cifar100

(x_train, y_train), (x_test, y_test) = cifar100.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

print("x_train.shape = %s" % str(x_train.shape))
print("y_train.shape = %s" % str(x_train.shape))

x_train = x_train.reshape([x_train.shape[0],
                           x_train.shape[1],
                           x_train.shape[2],3])

x_test = x_test.reshape([x_test.shape[0],
                           x_test.shape[1],
                           x_test.shape[2],3])


x_train = np.array(tf.keras.backend.resize_images(x_train, height_factor=2,width_factor=2, data_format='channels_last',interpolation='bilinear'))
x_test = np.array(tf.keras.backend.resize_images(x_test, height_factor=2,width_factor=2, data_format='channels_last',interpolation='bilinear'))

print("x_train.shape = %s" % str(x_train.shape))
print("x_test.shape = %s" % str(x_test.shape))

print("y_train.shape = %s" % str(y_train.shape))
print("y_test.shape = %s" % str(y_test.shape))

input_shape = x_train.shape[1]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 11s 0us/step
# x_train.shape = (50000, 32, 32, 3)
# y_train.shape = (50000, 32, 32, 3)
# x_train.shape = (50000, 64, 64, 3)
# x_test.shape = (10000, 64, 64, 3)
# y_train.shape = (50000, 1)
# y_test.shape = (10000, 1)

# %%
# Network modules
def conv_batchnorm_relu(net_in,filters,kernel_size,strides):
  net = tf.keras.layers.Conv2D(filters,kernel_size=(kernel_size,kernel_size),
                               strides=(strides,strides),
                               padding='same',
                               kernel_initializer='he_normal',
                               activation=None)(net_in)
  net = tf.keras.layers.BatchNormalization()(net)
  net = tf.keras.layers.Activation(activation='relu')(net)
  return net


def convdw_batchnorm_relu(net_in,filters,depth_multiplier,kernel_size,strides):
  net = tf.keras.layers.DepthwiseConv2D(kernel_size=(kernel_size,kernel_size),
                                        strides=(strides,strides),
                                        depth_multiplier=depth_multiplier,
                                        padding='same',
                                        kernel_initializer='he_normal',
                                        activation=None)(net_in)
  net = tf.keras.layers.BatchNormalization()(net)
  net = conv_batchnorm_relu(net,filters,1,1)

  return net


depth_multiplier=1
# moblienet model
net_in = tf.keras.layers.Input(shape=(input_shape,input_shape,3))
net = tf.keras.layers.Conv2D(64,kernel_size=(9,9),strides=1,padding='valid', kernel_initializer='he_normal',activation='relu')(net_in)
# net = convdw_batchnorm_relu(net,32,3,1)
# net = convdw_batchnorm_relu(net,64,3,2)
net = convdw_batchnorm_relu(net,128,depth_multiplier,3,1)
net = convdw_batchnorm_relu(net,128,depth_multiplier,3,2)
net = convdw_batchnorm_relu(net,256,depth_multiplier,3,1)
net = convdw_batchnorm_relu(net,256,depth_multiplier,3,2)
net = convdw_batchnorm_relu(net,512,depth_multiplier,3,1)
net = convdw_batchnorm_relu(net,512,depth_multiplier,3,1)
net = convdw_batchnorm_relu(net,512,depth_multiplier,3,1)
net = convdw_batchnorm_relu(net,512,depth_multiplier,3,1)
net = convdw_batchnorm_relu(net,512,depth_multiplier,3,1)
net = convdw_batchnorm_relu(net,512,depth_multiplier,3,2)
net = convdw_batchnorm_relu(net,1024,depth_multiplier,3,2)
net = tf.keras.layers.GlobalAvgPool2D(data_format='channels_last')(net)
net = tf.keras.layers.Dropout(0.4)(net)
net = tf.keras.layers.Dense(units=1000,activation='softmax')(net)
model = tf.keras.models.Model(inputs=net_in,outputs=net)


opt_fn = tf.keras.optimizers.Adam(learning_rate=1e-4,
                                beta_1=0.9,
                                beta_2=0.999)

# 'sparse_categorical_crossentropy' is for integer labels
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

tensorboard_callback = TensorBoard(log_dir=LOG_DIR, 
                           histogram_freq=1,
                           write_graph=True,
                           write_images=True)

# %%
# model training and evaluation part
training_epochs = 20
batch_size = 128
model.summary()
model.fit(x_train, y_train, 
          epochs=training_epochs,
          validation_data=(x_test, y_test),
          batch_size=batch_size,
          callbacks=[tensorboard_callback])
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 56, 56, 64)        15616
# _________________________________________________________________
# depthwise_conv2d (DepthwiseC (None, 56, 56, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 56, 56, 64)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 56, 56, 128)       8320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# activation (Activation)      (None, 56, 56, 128)       0
# _________________________________________________________________
# depthwise_conv2d_1 (Depthwis (None, 28, 28, 128)       1280
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       16512
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# depthwise_conv2d_2 (Depthwis (None, 28, 28, 128)       1280
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 256)       33024
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 28, 28, 256)       1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 256)       0
# _________________________________________________________________
# depthwise_conv2d_3 (Depthwis (None, 14, 14, 256)       2560
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       65792
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 14, 14, 256)       1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 14, 14, 256)       0
# _________________________________________________________________
# depthwise_conv2d_4 (Depthwis (None, 14, 14, 256)       2560
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 512)       131584
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_4 (Activation)    (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_5 (Depthwis (None, 14, 14, 512)       5120
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 512)       262656
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_6 (Depthwis (None, 14, 14, 512)       5120
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 512)       262656
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_6 (Activation)    (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_7 (Depthwis (None, 14, 14, 512)       5120
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 512)       262656
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_7 (Activation)    (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_8 (Depthwis (None, 14, 14, 512)       5120
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 512)       262656
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 14, 14, 512)       2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 14, 14, 512)       0
# _________________________________________________________________
# depthwise_conv2d_9 (Depthwis (None, 7, 7, 512)         5120
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 512)         262656
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 7, 7, 512)         0
# _________________________________________________________________
# depthwise_conv2d_10 (Depthwi (None, 4, 4, 512)         5120
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 1024)        525312
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 4, 4, 1024)        4096
# _________________________________________________________________
# activation_10 (Activation)   (None, 4, 4, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              1025000
# =================================================================
# Total params: 3,208,552
# Trainable params: 3,191,016
# Non-trainable params: 17,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 82s 2ms/sample - loss: 3.6561 - accuracy: 0.1463 - val_loss: 5.2094 - val_accuracy: 0.0100
# Epoch 2/20
# 50000/50000 [==============================] - 73s 1ms/sample - loss: 2.7005 - accuracy: 0.3052 - val_loss: 3.4611 - val_accuracy: 0.2089
# Epoch 3/20
# 43264/50000 [========================>.....] - ETA: 9s - loss: 2.2130 - accuracy: 0.4099

# %%
# prediction 

test_input = x_test[300,:,:,:]
pred_y = model.predict(test_input.reshape([1,64,64,3]))

plt.figure(1)
plt.imshow(test_input.reshape([64,64,3]))
plt.title("input")
print("model prediction = %s"% pred_y.argmax())
